# %%
dbutils.help()

# %%
dbutils.fs.help()

# %%
files = dbutils.fs.ls("dbfs:/databricks-datasets")

for files in files:
    print(f"{files.name:<40} {files.size:<10}")

# %%
dbutils.fs.mkdirs("/Workspace/Shared/config")

config_content = """
env=development
raw_path=raw_data_path
silver_path=silver_data_path
gold_path=gold_data_path"""

dbutils.fs.put("/Workspace/Shared/config/application.conf", config_content, overwrite=True)

# %%
dbutils.fs.rm("/Workspace/Shared/",True)

# %%
result=dbutils.notebook.run("/Workspace/aws_databricks/2_row_counter.py",60, {"file_path_value":"/databricks-datasets/Rdatasets/data-001/csv/ggplot2/diamonds.csv"})

print(f"Result: {result}")
