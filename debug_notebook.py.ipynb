# %%
from pyspark.sql import Row
from datetime import datetime, date


df = spark.createDataFrame([Row(id = 1, name ='Jonas', birthday=date(2000,1, 1)),
                            Row(id = 2, name = 'Marry', birthday=date(2002,2,1)),
                            Row(id = 4, name = 'Susan', birthday=date(2000,3,1))])

x=10
y=20
z=30

#this is debug examples only used in cluster based
