# %%
# dbutils.widgets.text("file_path_value", 
#                     "/databricks-datasets/Rdatasets/data-001/csv/ggplot2/diamonds.csv","provide file path")

file_path = dbutils.widgets.get("file_path_value")
print(f"Got input: {file_path}")

# %%
df = (spark.read.format("csv")
      .option("Header", True)
      .option("InferSchema", True)
      .load(file_path))

row_count=df.count()
print(f"Row count: {row_count}")


dbutils.notebook.exit(row_count)
